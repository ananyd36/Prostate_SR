# %%
import os
import sys
import traceback
from pathlib import Path

import numpy as np
from PIL import Image
import pydicom

# =========================================================
# 1. SETTINGS
# =========================================================

# Where all the patient folders are living right now
DATA_FOLDER = Path("/blue/eel6935/anany.sharma/Final_Project_EEL6935/ProstateMRI_T2")

# The name of the new folder we will make for the pictures
SAVE_FOLDER = "png_conv"

# We ignore scans that have fewer than 3 slices (too small)
SMALLEST_ALLOWED = 3

# =========================================================
# 2. HELPER TOOLS
# =========================================================

def get_patient_folders(main_folder: Path):
    """
    Finds all the sub-folders inside the main folder.
    """
    # Look for items that are actual directories
    folders = [x for x in main_folder.iterdir() if x.is_dir()]
    folders.sort()
    return folders


def make_image_bright_and_clear(image_3d: np.ndarray) -> np.ndarray:
    """
    Fixes the brightness of the 3D scan so it looks good as a picture.
    It stretches the pixel values to fit between 0 and 255.
    """
    # Convert to decimal numbers for math
    data = image_3d.astype(np.float32)
    
    # Find the very dark (1%) and very bright (99%) dots
    low_val, high_val = np.percentile(data, [1, 99])

    # Safety check: if the math breaks, just use the simple min/max
    if high_val <= low_val:
        min_v, max_v = data.min(), data.max()
        if max_v <= min_v:
            # If the image is empty, return a black image
            return np.zeros_like(data, dtype=np.uint8)
        
        # Stretch min to 0 and max to 1
        data = (data - min_v) / (max_v - min_v)
        # Multiply by 255 to make it a standard picture number
        data = (data * 255.0).clip(0, 255).astype(np.uint8)
        return data

    # Clip the super bright outliers so they don't ruin the contrast
    data = np.clip(data, low_val, high_val)
    # Stretch to 0-1 range
    data = (data - low_val) / (high_val - low_val + 1e-8)
    # Convert to 0-255 range
    data = (data * 255.0).clip(0, 255).astype(np.uint8)
    return data


# [Image of MRI anatomical planes]

def rate_this_scan(header_info, file_count: int) -> float:
    """
    This function gives points to a scan to decide if it is the "best" one.
    We want 'T2' type scans that are cut horizontally ('Axial').
    """
    points = 0.0
    
    # Get the description text and make it lowercase
    desc_text = str(getattr(header_info, "SeriesDescription", "")).lower()
    machine_type = str(getattr(header_info, "Modality", "")).lower()

    # Give 5 points if it says T2 (the type of MRI contrast we want)
    if "t2" in desc_text:
        points += 5.0
    
    # Give 3 points if it is cut horizontally (Axial / Transverse)
    # This helps us ignore scans cut from the side or front.
    if "tra" in desc_text or "ax" in desc_text or "trans" in desc_text:
        points += 3.0
    
    # Give 1 point if it's definitely an MRI machine
    if machine_type == "mr":
        points += 1.0

    # Give a tiny bonus for having more slices (bigger is usually better)
    points += file_count / 100.0 

    return points


def read_dicom_files(file_list):
    """
    Reads a bunch of .dcm files and stacks them into a 3D block.
    """
    loaded_slices = []
    
    for current_file in file_list:
        try:
            # Read the medical file
            data = pydicom.dcmread(str(current_file))
            
            # Find the "page number" of this slice so we can sort them later
            page_num = int(getattr(data, "InstanceNumber", 0))

            # Get the raw picture dots
            pixels = data.pixel_array.astype(np.float32)

            # Apply any math corrections saved in the file header
            slope = float(getattr(data, "RescaleSlope", 1.0))
            intercept = float(getattr(data, "RescaleIntercept", 0.0))
            pixels = pixels * slope + intercept

            loaded_slices.append((page_num, pixels))
        except Exception as error:
            print(f"    ⚠️ Oops, could not read {current_file}: {error}")
            traceback.print_exc()

    if not loaded_slices:
        return None, None

    # Put the pages in order (Page 1, Page 2, Page 3...)
    loaded_slices.sort(key=lambda x: x[0])
    
    # Extract just the page numbers
    page_nums = [s[0] for s in loaded_slices]
    
    # Stack the pixel arrays on top of each other like pancakes
    # Result shape: (Height, Width) -> (Count, Height, Width)
    volume_block = np.stack([s[1] for s in loaded_slices], axis=0)
    
    return volume_block, page_nums


# =========================================================
# 3. MAIN PROGRAM
# =========================================================

def run_conversion():
    # 1. Find all patients
    all_patients = get_patient_folders(DATA_FOLDER)
    print(f"Found {len(all_patients)} patient folders in {DATA_FOLDER}")

    for patient_path in all_patients:
        print(f"\n=== Working on: {patient_path.name} ===")

        # Check if we already finished this patient
        already_done = list(patient_path.rglob("*.png"))
        if len(already_done) > 0:
            print(f"  ✅ Found {len(already_done)} PNGs already. Skipping.")
            continue

        # Find all .dcm files for this patient
        dicom_files = list(patient_path.rglob("*.dcm"))
        if not dicom_files:
            print("  ⚠️ No medical files found here. Skipping.")
            continue

        print(f"  Found {len(dicom_files)} raw files.")

        # 2. Sort files into groups (called Series)
        # We use a dictionary to group them by their unique ID
        groups = {} 
        for f in dicom_files:
            try:
                # Read just the header info (fast)
                header = pydicom.dcmread(str(f), stop_before_pixels=True)
                
                # Get the Series ID
                uid = getattr(header, "SeriesInstanceUID", None) or "unknown_id"
                
                if uid not in groups:
                    groups[uid] = {"files": [], "header": header}
                groups[uid]["files"].append(f)
            except Exception as e:
                print(f"    ⚠️ Header error on {f}: {e}")
                traceback.print_exc()

        if not groups:
            print("  ⚠️ No valid groups found. Skipping.")
            continue

        # 3. Pick the best group (The T2 Axial one)
        winner_id = None
        highest_score = -1000000.0
        
        for uid, info in groups.items():
            head = info["header"]
            files = info["files"]
            
            # Calculate score
            score = rate_this_scan(head, len(files))
            desc = str(getattr(head, "SeriesDescription", ""))
            
            print(f"  Group {uid} | {len(files)} imgs | Desc='{desc}' | Score={score:.2f}")
            
            # Update the winner if this one is better and big enough
            if len(files) >= SMALLEST_ALLOWED and score > highest_score:
                highest_score = score
                winner_id = uid

        if winner_id is None:
            print(f"  ⚠️ No group was good enough (needs {SMALLEST_ALLOWED}+ slices). Skipping.")
            continue

        winner_data = groups[winner_id]
        winner_files = winner_data["files"]
        winner_desc = str(getattr(winner_data["header"], "SeriesDescription", ""))
        
        print(f"  👉 Winner is: {winner_id} ({len(winner_files)} slices, '{winner_desc}')")

        # 4. Load the winner into memory
        volume_3d, _ = read_dicom_files(winner_files)
        if volume_3d is None:
            print("  ⚠️ Failed to load pixel data. Skipping.")
            continue

        print(f"  Raw size: {volume_3d.shape}")

        # 5. Make it look nice (0-255 brightness)
        clean_volume = make_image_bright_and_clear(volume_3d)
        print(f"  Clean size: {clean_volume.shape}, Type={clean_volume.dtype}")

        # 6. Save as PNG pictures
        target_folder = patient_path / SAVE_FOLDER
        target_folder.mkdir(parents=True, exist_ok=True)

        count = clean_volume.shape[0]
        for i in range(count):
            # Get one slice
            single_slice = clean_volume[i] 
            # Make a picture object
            pic = Image.fromarray(single_slice)
            # Save it
            save_name = target_folder / f"slice_{i:03d}.png"
            pic.save(save_name)

        print(f"  ✅ Saved {count} pictures to {target_folder}")

    print("\nAll done!")


if __name__ == "__main__":
    run_conversion()
# Out:
# Found 842 patient folders in /blue/eel6935/anany.sharma/Final_Project_EEL6935/ProstateMRI_T2
#
# === Working on: Prostate-MRI-US-Biopsy-0001 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0002 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0003 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0005 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0006 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0007 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0008 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0009 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0012 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0013 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0014 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0015 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0019 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0020 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0021 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0022 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0023 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0024 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0027 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0028 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0029 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0030 ===
#   ✅ Found 48 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0031 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0032 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0033 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0035 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0036 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0037 ===
#   ✅ Found 144 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0038 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0039 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0040 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0042 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0044 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0045 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0047 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0049 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0050 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0051 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0052 ===
#   ✅ Found 120 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0053 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0054 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0055 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0057 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0058 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0059 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0060 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0061 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0062 ===
#   ✅ Found 34 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0065 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0066 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0067 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0069 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0071 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0072 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0073 ===
#   ✅ Found 21 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0075 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0076 ===
#   ✅ Found 80 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0077 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0078 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0079 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0080 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0081 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0083 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0084 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0085 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0086 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0089 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0090 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0092 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0093 ===
#   ✅ Found 64 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0094 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0095 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0096 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0098 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0102 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0103 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0104 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0105 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0108 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0109 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0110 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0112 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0114 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0117 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0118 ===
#   ✅ Found 64 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0119 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0121 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0122 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0124 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0125 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0126 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0127 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0128 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0129 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0130 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0131 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0132 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0133 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0134 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0135 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0136 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0137 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0138 ===
#   ✅ Found 59 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0139 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0140 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0141 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0143 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0144 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0145 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0152 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0153 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0154 ===
#   ✅ Found 88 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0155 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0157 ===
#   ✅ Found 26 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0159 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0161 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0162 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0164 ===
#   ✅ Found 64 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0166 ===
#   ✅ Found 33 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0167 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0168 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0169 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0172 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0173 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0174 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0177 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0178 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0179 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0180 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0181 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0183 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0184 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0185 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0186 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0187 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0188 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0189 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0190 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0192 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0194 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0195 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0198 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0200 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0201 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0202 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0203 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0205 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0207 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0208 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0209 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0210 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0211 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0212 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0213 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0214 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0215 ===
#   ✅ Found 28 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0216 ===
#   ✅ Found 26 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0217 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0218 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0219 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0220 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0221 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0223 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0224 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0225 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0226 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0228 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0229 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0230 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0231 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0234 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0235 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0237 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0238 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0239 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0240 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0242 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0243 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0244 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0245 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0247 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0248 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0250 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0251 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0255 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0256 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0258 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0260 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0261 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0262 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0264 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0266 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0267 ===
#   ✅ Found 59 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0269 ===
#   ✅ Found 64 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0271 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0273 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0274 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0275 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0277 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0278 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0280 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0281 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0282 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0283 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0284 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0285 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0286 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0288 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0289 ===
#   ✅ Found 22 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0290 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0291 ===
#   ✅ Found 64 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0293 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0295 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0296 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0297 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0298 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0299 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0300 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0301 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0302 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0303 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0304 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0305 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0306 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0307 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0308 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0309 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0310 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0311 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0312 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0314 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0315 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0316 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0318 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0319 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0321 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0323 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0324 ===
#   ✅ Found 64 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0326 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0327 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0328 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0329 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0331 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0332 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0333 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0334 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0335 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0336 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0338 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0339 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0340 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0341 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0342 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0343 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0344 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0345 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0346 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0347 ===
#   ✅ Found 28 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0348 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0349 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0350 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0352 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0353 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0354 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0355 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0356 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0357 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0358 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0359 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0360 ===
#   ✅ Found 52 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0361 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0362 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0363 ===
#   ✅ Found 24 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0364 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0365 ===
#   ✅ Found 59 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0366 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0367 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0368 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0370 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0371 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0372 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0373 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0374 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0376 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0377 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0379 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0381 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0382 ===
#   ✅ Found 59 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0383 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0386 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0387 ===
#   ✅ Found 28 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0388 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0390 ===
#   ✅ Found 80 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0392 ===
#   ✅ Found 20 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0393 ===
#   ✅ Found 34 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0394 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0395 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0396 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0399 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0400 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0401 ===
#   ✅ Found 33 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0402 ===
#   ✅ Found 72 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0405 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0406 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0407 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0409 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0411 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0412 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0413 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0414 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0416 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0419 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0420 ===
#   ✅ Found 24 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0421 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0423 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0424 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0425 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0427 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0429 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0431 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0432 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0434 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0435 ===
#   ✅ Found 25 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0436 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0437 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0439 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0440 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0442 ===
#   ✅ Found 72 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0443 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0445 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0446 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0447 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0448 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0451 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0452 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0453 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0454 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0455 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0457 ===
#   ✅ Found 64 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0459 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0460 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0461 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0462 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0464 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0465 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0467 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0468 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0469 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0470 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0471 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0472 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0473 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0475 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0478 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0479 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0480 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0482 ===
#   ✅ Found 59 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0484 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0485 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0486 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0487 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0488 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0489 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0491 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0492 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0493 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0494 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0495 ===
#   ✅ Found 64 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0496 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0498 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0499 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0500 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0501 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0502 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0504 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0507 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0509 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0510 ===
#   ✅ Found 72 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0512 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0513 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0517 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0520 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0521 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0522 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0523 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0524 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0525 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0526 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0528 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0529 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0531 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0532 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0533 ===
#   ✅ Found 30 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0534 ===
#   ✅ Found 72 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0535 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0536 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0539 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0545 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0546 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0548 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0549 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0550 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0551 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0552 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0554 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0555 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0556 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0557 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0558 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0559 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0561 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0563 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0564 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0565 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0566 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0567 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0568 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0569 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0572 ===
#   ✅ Found 26 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0573 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0574 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0575 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0576 ===
#   ✅ Found 24 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0577 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0578 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0579 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0581 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0582 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0583 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0584 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0585 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0587 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0591 ===
#   ✅ Found 36 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0592 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0593 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0594 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0595 ===
#   ✅ Found 72 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0596 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0597 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0598 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0599 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0600 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0601 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0604 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0605 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0606 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0607 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0608 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0609 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0610 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0612 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0613 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0615 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0616 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0618 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0619 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0621 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0622 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0623 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0624 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0625 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0627 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0628 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0629 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0630 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0631 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0632 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0634 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0635 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0638 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0639 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0640 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0641 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0642 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0643 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0645 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0646 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0650 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0651 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0652 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0653 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0654 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0655 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0656 ===
#   ✅ Found 20 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0657 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0659 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0660 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0661 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0662 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0663 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0664 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0665 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0666 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0667 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0668 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0670 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0671 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0672 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0673 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0674 ===
#   ✅ Found 112 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0675 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0676 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0677 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0678 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0679 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0682 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0683 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0684 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0685 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0686 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0687 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0688 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0689 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0690 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0691 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0692 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0693 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0695 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0696 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0697 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0698 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0701 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0702 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0703 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0704 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0706 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0707 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0708 ===
#   ✅ Found 26 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0709 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0710 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0711 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0712 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0713 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0714 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0716 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0717 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0718 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0720 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0721 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0722 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0723 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0725 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0726 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0727 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0728 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0729 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0730 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0731 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0732 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0734 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0736 ===
#   ✅ Found 40 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0737 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0739 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0741 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0742 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0744 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0745 ===
# ...
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0895 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0896 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0897 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0898 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0900 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0902 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0903 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0904 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0905 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0906 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0907 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0908 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0911 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0914 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0915 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0916 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0917 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0918 ===
#   ✅ Found 21 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0921 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0922 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0923 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0924 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0925 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0927 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0928 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0929 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0930 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0931 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0932 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0934 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0936 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0938 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0939 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0942 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0943 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0944 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0945 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0946 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0949 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0950 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0951 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0953 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0955 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0956 ===
#   ✅ Found 80 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0957 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0958 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0959 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0960 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0961 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0962 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0963 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0964 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0966 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0970 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0971 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0972 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0973 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0974 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0975 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0976 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0978 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0979 ===
#   ✅ Found 64 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0980 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0981 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0983 ===
#   ✅ Found 80 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0984 ===
#   ✅ Found 36 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0985 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0986 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0987 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0988 ===
#   ✅ Found 26 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0991 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0992 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0993 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0996 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0997 ===
#   ✅ Found 64 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0998 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-0999 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1000 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1002 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1003 ===
#   ✅ Found 28 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1004 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1005 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1006 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1007 ===
#   ✅ Found 28 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1008 ===
#   ✅ Found 64 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1009 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1010 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1011 ===
#   ✅ Found 29 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1012 ===
#   ✅ Found 30 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1013 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1017 ===
#   ✅ Found 28 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1018 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1019 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1020 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1021 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1022 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1023 ===
#   ✅ Found 28 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1024 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1026 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1027 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1028 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1029 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1030 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1036 ===
#   ✅ Found 20 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1037 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1038 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1039 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1042 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1043 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1044 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1045 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1046 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1048 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1050 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1052 ===
#   ✅ Found 20 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1053 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1055 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1058 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1059 ===
#   ✅ Found 30 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1060 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1062 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1064 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1065 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1066 ===
#   ✅ Found 25 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1067 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1068 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1069 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1070 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1072 ===
#   ✅ Found 26 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1073 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1074 ===
#   ✅ Found 24 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1075 ===
#   ✅ Found 38 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1078 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1080 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1081 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1084 ===
#   ✅ Found 26 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1086 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1087 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1088 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1090 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1092 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1094 ===
#   ✅ Found 32 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1096 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1097 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1098 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1099 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1102 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1103 ===
#   ✅ Found 27 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1105 ===
#   ✅ Found 26 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1106 ===
#   ✅ Found 136 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1109 ===
#   ✅ Found 20 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1110 ===
#   ✅ Found 19 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1111 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1113 ===
#   ✅ Found 24 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1114 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1115 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1116 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1117 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1120 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1121 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1122 ===
#   ✅ Found 64 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1123 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1124 ===
#   ✅ Found 32 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1126 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1127 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1128 ===
#   ✅ Found 24 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1129 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1130 ===
#   ✅ Found 72 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1131 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1132 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1133 ===
#   ✅ Found 30 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1134 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1135 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1136 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1137 ===
#   ✅ Found 24 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1138 ===
#   ✅ Found 26 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1140 ===
#   ✅ Found 25 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1141 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1142 ===
#   ✅ Found 25 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1143 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1146 ===
#   ✅ Found 26 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1148 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1149 ===
#   ✅ Found 25 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1150 ===
#   ✅ Found 25 PNGs already. Skipping.
#
# === Working on: Prostate-MRI-US-Biopsy-1151 ===
#   ✅ Found 60 PNGs already. Skipping.
#
# All done!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from pathlib import Path
from tqdm.auto import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# Where to save models
DATA_ROOT = Path("/blue/eel6935/anany.sharma/Final_Project_EEL6935/ProstateMRI_T2_MR_png")
MODEL_DIR = DATA_ROOT / "models_interp"
MODEL_DIR.mkdir(parents=True, exist_ok=True)
# Out:
# Using device: cuda

# %%
import os
import random
import math
from pathlib import Path
from collections import defaultdict
import time 

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, UnidentifiedImageError
from tqdm.auto import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.amp import GradScaler, autocast

# Attempt to load the specialized medical image library
try:
    import pydicom
except ImportError as e:
    raise ImportError("The 'pydicom' library is required.") from e

# Determine the processing hardware
print("PyTorch Version:", torch.__version__)
processing_device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
amp_dev_type = "cuda" if torch.cuda.is_available() else "cpu"
gpu_count = torch.cuda.device_count()
print("Using hardware:", processing_device, "| Available GPUs:", gpu_count)

USE_MULTI_GPU = (processing_device.type == "cuda" and gpu_count > 1)
if USE_MULTI_GPU:
    print(f"✅ Parallel Processing enabled across {gpu_count} GPUs")

# --- Utility Functions ---
def extract_model_weights(model_instance):
    return model_instance.module.state_dict() if isinstance(model_instance, nn.DataParallel) else model_instance.state_dict()

def inject_model_weights(model_instance, weight_dict):
    if isinstance(model_instance, nn.DataParallel):
        model_instance.module.load_state_dict(weight_dict)
    else:
        model_instance.load_state_dict(weight_dict)

# ============================================================
# 1. CONFIGURATION
# ============================================================

RAW_SCAN_PATH = Path("/blue/eel6935/anany.sharma/Final_Project_EEL6935/ProstateMRI_T2")
PROCESSED_PNG_PATH = Path("/blue/eel6935/anany.sharma/Final_Project_EEL6935/ProstateMRI_T2_MR_png")

TRAIN_SET_HR_DIR = PROCESSED_PNG_PATH / "training_data" / "HR"
VALIDATION_SET_HR_DIR = PROCESSED_PNG_PATH / "validation_data" / "HR"
TEST_SET_HR_DIR = PROCESSED_PNG_PATH / "testing_data" / "HR"

for d in [TRAIN_SET_HR_DIR, VALIDATION_SET_HR_DIR, TEST_SET_HR_DIR]:
    d.mkdir(parents=True, exist_ok=True)

TARGET_HEIGHT, TARGET_WIDTH = 256, 256
TRAIN_RATIO, VALIDATION_RATIO, TEST_RATIO = 0.7, 0.15, 0.15

BATCH_SIZE_PER_STEP = 8
DATA_WORKER_THREADS = 4 
TOTAL_TRAINING_EPOCHS = 20 
LEARNING_RATE = 1e-4 

random.seed(42)

# ============================================================
# 2. DATA PREPARATION (Robust)
# ============================================================

def SafeImageCheck(path):
    """
    Tries to open an image to verify it is not corrupt.
    Returns True if safe, False if corrupt.
    """
    try:
        with Image.open(path) as img:
            img.verify() 
        return True
    except (OSError, UnidentifiedImageError):
        print(f"⚠️ Found corrupt image: {path.name}. Skipping associated triplets.")
        return False

def read_patient_scan_volume(patient_directory, target_dim=(256, 256)):
    """Reads DICOM files, normalizes, and stacks them into a volume."""
    dicom_files = sorted(patient_directory.rglob("*.dcm"))
    if len(dicom_files) == 0: return None

    slice_data_list = []
    for file_path in dicom_files:
        try:
            ds = pydicom.dcmread(file_path, stop_before_pixels=False)
        except Exception: continue
        
        if not hasattr(ds, "pixel_array"): continue
        
        raw_image = ds.pixel_array.astype(np.float32)
        rescale_slope = float(getattr(ds, "RescaleSlope", 1.0))
        rescale_intercept = float(getattr(ds, "RescaleIntercept", 0.0))
        processed_image = raw_image * rescale_slope + rescale_intercept
        instance_number = int(getattr(ds, "InstanceNumber", len(slice_data_list)))
        slice_data_list.append((instance_number, processed_image))

    if len(slice_data_list) < 3: return None

    slice_data_list.sort(key=lambda x: x[0])
    
    resized_slices_list = []
    for inst, img in slice_data_list:
        img_min = img.min()
        img_max = img.max()
        if img_max > img_min:
            img_norm = (img - img_min) / (img_max - img_min)
        else:
            img_norm = np.zeros_like(img)
        
        img_uint8 = (img_norm * 255).astype(np.uint8)
        pil_image = Image.fromarray(img_uint8)
        resized_pil_image = pil_image.resize((target_dim[1], target_dim[0]), resample=Image.BILINEAR)
        resized_np_array = np.array(resized_pil_image, dtype=np.float32)
        resized_slices_list.append(resized_np_array)
    
    stacked_volume = np.stack(resized_slices_list, axis=0)
    volume_min = float(stacked_volume.min())
    volume_max = float(stacked_volume.max())
    if volume_max <= volume_min: return None 
        
    stacked_volume = (stacked_volume - volume_min) / (volume_max - volume_min + 1e-6)
    return (stacked_volume * 255.0).clip(0, 255).astype(np.uint8)

def process_and_organize_data():
    """Divides patient folders and creates robust image triplets."""
    all_patient_dirs = sorted([d for d in RAW_SCAN_PATH.iterdir() if d.is_dir()])
    if len(all_patient_dirs) == 0:
        raise RuntimeError(f"No patient folders found in {RAW_SCAN_PATH}")

    random.shuffle(all_patient_dirs)
    total_patients = len(all_patient_dirs)
    
    n_train_pats = int(total_patients * TRAIN_RATIO)
    n_val_pats = int(total_patients * VALIDATION_RATIO)

    train_patients = all_patient_dirs[:n_train_pats]
    validation_patients = all_patient_dirs[n_train_pats:n_train_pats+n_val_pats]
    test_patients = all_patient_dirs[n_train_pats+n_val_pats:]

    patient_group_map = {}
    for p in train_patients: patient_group_map[p.name] = "train"
    for p in validation_patients: patient_group_map[p.name] = "val"
    for p in test_patients: patient_group_map[p.name] = "test"

    print(f"Total patients: {total_patients} | Train={len(train_patients)}, Val={len(validation_patients)}, Test={len(test_patients)}")

    train_slice_triplets, val_slice_triplets, test_slice_triplets = [], [], []

    split_to_output_dir = {
        "train": TRAIN_SET_HR_DIR,
        "val": VALIDATION_SET_HR_DIR,
        "test": TEST_SET_HR_DIR,
    }

    for patient_folder in tqdm(all_patient_dirs, desc="Preparing Data"):
        patient_id = patient_folder.name
        split_group = patient_group_map[patient_id]
        output_folder = split_to_output_dir[split_group]

        scan_volume = read_patient_scan_volume(patient_folder)
        if scan_volume is None: continue

        num_slices, H, W = scan_volume.shape
        if num_slices < 3: continue

        png_path_list = []
        for slice_index in range(num_slices):
            png_filename = f"{patient_id}_slice_{slice_index:03d}.png"
            png_filepath = output_folder / png_filename

            if not png_filepath.exists():
                image_slice = Image.fromarray(scan_volume[slice_index])
                image_slice.save(png_filepath)
            png_path_list.append(png_filepath)

        # Create triplets ONLY if all images are safe
        triplets_for_patient = []
        for i in range(1, num_slices - 1):
            prev_p = png_path_list[i - 1]
            mid_p = png_path_list[i]
            next_p = png_path_list[i + 1]
            
            # Robust Check: Only add triplet if files are valid
            if SafeImageCheck(prev_p) and SafeImageCheck(mid_p) and SafeImageCheck(next_p):
                triplets_for_patient.append((prev_p, mid_p, next_p))

        if split_group == "train": train_slice_triplets.extend(triplets_for_patient)
        elif split_group == "val": val_slice_triplets.extend(triplets_for_patient)
        else: test_slice_triplets.extend(triplets_for_patient)

    print(f"Data Ready: Train={len(train_slice_triplets)}, Val={len(val_slice_triplets)}, Test={len(test_slice_triplets)}")
    return train_slice_triplets, val_slice_triplets, test_slice_triplets

# ============================================================
# 3. PYTORCH DATA HANDLING
# ============================================================

def load_image_to_tensor(image_path, target_dim=(TARGET_HEIGHT, TARGET_WIDTH)):
    try:
        img = Image.open(image_path).convert("F") 
        if img.size != (target_dim[1], target_dim[0]):
            img = img.resize((target_dim[1], target_dim[0]), resample=Image.BILINEAR)
        numpy_array = np.array(img, dtype=np.float32) / 255.0
        return torch.from_numpy(numpy_array).unsqueeze(0)
    except Exception:
        # Fallback for safety (should be caught by SafeImageCheck mostly)
        return torch.zeros((1, target_dim[0], target_dim[1]), dtype=torch.float32)

class ScanSliceSequenceDataset(Dataset):
    def __init__(self, list_of_triplets):
        self.triplets = list_of_triplets

    def __len__(self): return len(self.triplets)

    def __getitem__(self, index):
        prev_path, mid_path, next_path = self.triplets[index]
        prev_slice = load_image_to_tensor(prev_path)
        mid_slice = load_image_to_tensor(mid_path)
        next_slice = load_image_to_tensor(next_path)
        
        model_input_x = torch.cat([prev_slice, next_slice], dim=0) 
        model_target_y = mid_slice
        return model_input_x, model_target_y

# ============================================================
# 4. METRICS & MODELS
# ============================================================

def calculate_psnr(prediction, ground_truth, max_value=1.0):
    mse = F.mse_loss(prediction, ground_truth, reduction="mean")
    if mse.item() == 0: return 99.0 
    return 20 * torch.log10(max_value / torch.sqrt(mse))

# 


class SimpleConvolutionalModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.feature_extractor = nn.Conv2d(2, 64, 9, padding=4)
        self.non_linear_map = nn.Conv2d(64, 32, 5, padding=2)
        self.reconstruction = nn.Conv2d(32, 1, 5, padding=2)
    def forward(self, x):
        x = F.relu(self.feature_extractor(x))
        x = F.relu(self.non_linear_map(x))
        return torch.sigmoid(self.reconstruction(x))

class DeeperConvolutionalModel(nn.Module):
    def __init__(self):
        super().__init__()
        layer_list = []
        input_channels = 2
        for output_channels in [64, 64, 64, 32]:
            layer_list.append(nn.Conv2d(input_channels, output_channels, 3, padding=1))
            layer_list.append(nn.ReLU(inplace=True))
            input_channels = output_channels
        layer_list.append(nn.Conv2d(input_channels, 1, 3, padding=1))
        self.network = nn.Sequential(*layer_list)
    def forward(self, x): return torch.sigmoid(self.network(x))

# GAN Components
class UNetConvBlock(nn.Module):
    def __init__(self, input_channels, output_channels, is_downsample=True):
        super().__init__()
        if is_downsample:
            self.operation = nn.Sequential(
                nn.Conv2d(input_channels, output_channels, 4, 2, 1),
                nn.BatchNorm2d(output_channels),
                nn.LeakyReLU(0.2, True),
            )
        else:
            self.operation = nn.Sequential(
                nn.ConvTranspose2d(input_channels, output_channels, 4, 2, 1),
                nn.BatchNorm2d(output_channels),
                nn.ReLU(True),
            )
    def forward(self, x): return self.operation(x)

# 


class SliceSynthesizer(nn.Module):
    def __init__(self, base_filters=64):
        super().__init__()
        self.down_a = UNetConvBlock(2, base_filters, True)
        self.down_b = UNetConvBlock(base_filters, base_filters * 2, True)
        self.down_c = UNetConvBlock(base_filters * 2, base_filters * 4, True)
        self.deepest_point = nn.Sequential(nn.Conv2d(base_filters * 4, base_filters * 4, 3, 1, 1), nn.ReLU(True))
        self.up_c = UNetConvBlock(base_filters * 4, base_filters * 2, False)
        self.up_b = UNetConvBlock(base_filters * 4, base_filters, False)
        self.up_a = UNetConvBlock(base_filters * 2, base_filters, False)
        self.output_layer = nn.Conv2d(base_filters, 1, 3, padding=1)

    def forward(self, x):
        d_a = self.down_a(x)
        d_b = self.down_b(d_a)
        d_c = self.down_c(d_b)
        b = self.deepest_point(d_c)
        u_c = self.up_c(b); u_c = torch.cat([u_c, d_b], dim=1)
        u_b = self.up_b(u_c); u_b = torch.cat([u_b, d_a], dim=1)
        u_a = self.up_a(u_b)
        return torch.sigmoid(self.output_layer(u_a))

class RealityChecker(nn.Module):
    def __init__(self, input_channels=3, base_filters=64):
        super().__init__()
        layer_list = [
            nn.Conv2d(input_channels, base_filters, 4, 2, 1), nn.LeakyReLU(0.2, True),
            nn.Conv2d(base_filters, base_filters * 2, 4, 2, 1), nn.BatchNorm2d(base_filters * 2), nn.LeakyReLU(0.2, True),
            nn.Conv2d(base_filters * 2, base_filters * 4, 4, 2, 1), nn.BatchNorm2d(base_filters * 4), nn.LeakyReLU(0.2, True),
            nn.Conv2d(base_filters * 4, 1, 3, 1, 1),
        ]
        self.network = nn.Sequential(*layer_list)
    def forward(self, input_slices, target_or_fake_slice):
        return self.network(torch.cat([input_slices, target_or_fake_slice], dim=1))

# ============================================================
# 5. TRAINING & VALIDATION LOOPS
# ============================================================

def train_sr_model_one_epoch(model, data_loader, optimizer, precision_scaler, hardware_device):
    model.train()
    total_loss = 0.0
    total_psnr = 0.0
    batch_count = 0

    for input_x, target_y in tqdm(data_loader, desc="Train SR", leave=False):
        input_x = input_x.to(hardware_device)
        target_y = target_y.to(hardware_device)
        optimizer.zero_grad(set_to_none=True)

        with autocast(device_type=amp_dev_type, enabled=torch.cuda.is_available()):
            prediction = model(input_x)
            loss_value = F.l1_loss(prediction, target_y)

        precision_scaler.scale(loss_value).backward()
        precision_scaler.step(optimizer)
        precision_scaler.update()

        total_loss += loss_value.item()
        total_psnr += calculate_psnr(prediction.detach(), target_y.detach()).item()
        batch_count += 1

    return total_loss / batch_count, total_psnr / batch_count

@torch.no_grad()
def validate_sr_model(model, data_loader, hardware_device):
    model.eval()
    total_loss = 0.0
    total_psnr = 0.0
    batch_count = 0
    for input_x, target_y in tqdm(data_loader, desc="Val SR", leave=False):
        input_x = input_x.to(hardware_device)
        target_y = target_y.to(hardware_device)
        with autocast(device_type=amp_dev_type, enabled=torch.cuda.is_available()):
            prediction = model(input_x)
            loss_value = F.l1_loss(prediction, target_y)
        total_loss += loss_value.item()
        total_psnr += calculate_psnr(prediction, target_y).item()
        batch_count += 1
    return total_loss / batch_count, total_psnr / batch_count

def train_gan_model_one_epoch(Generator, Discriminator, data_loader, opt_G, opt_D, scaler_G, scaler_D, hardware_device):
    Generator.train()
    Discriminator.train()
    bce_loss_fn = nn.BCEWithLogitsLoss() 
    total_G_loss = 0.0
    total_D_loss = 0.0
    total_psnr = 0.0
    batch_count = 0

    for input_x, target_y in tqdm(data_loader, desc="Train GAN", leave=False):
        input_x = input_x.to(hardware_device)
        target_y = target_y.to(hardware_device)

        opt_D.zero_grad(set_to_none=True)
        with autocast(device_type=amp_dev_type, enabled=torch.cuda.is_available()):
            fake_image = Generator(input_x).detach() 
            pred_on_real = Discriminator(input_x, target_y) 
            pred_on_fake = Discriminator(input_x, fake_image)
            loss_D = 0.5 * (bce_loss_fn(pred_on_real, torch.ones_like(pred_on_real)) + bce_loss_fn(pred_on_fake, torch.zeros_like(pred_on_fake)))

        scaler_D.scale(loss_D).backward()
        scaler_D.step(opt_D)
        scaler_D.update()

        opt_G.zero_grad(set_to_none=True)
        with autocast(device_type=amp_dev_type, enabled=torch.cuda.is_available()):
            fake_image = Generator(input_x)
            pred_on_fake_for_G = Discriminator(input_x, fake_image) 
            loss_G = bce_loss_fn(pred_on_fake_for_G, torch.ones_like(pred_on_fake_for_G)) + F.l1_loss(fake_image, target_y) * 100.0

        scaler_G.scale(loss_G).backward()
        scaler_G.step(opt_G)
        scaler_G.update()

        total_G_loss += loss_G.item()
        total_D_loss += loss_D.item()
        total_psnr += calculate_psnr(fake_image.detach(), target_y.detach()).item()
        batch_count += 1

    return (total_G_loss/batch_count, total_D_loss/batch_count, total_psnr/batch_count)

@torch.no_grad()
def validate_gan_generator(Generator, data_loader, hardware_device):
    Generator.eval()
    total_l1 = 0.0
    total_psnr = 0.0
    batch_count = 0
    for input_x, target_y in tqdm(data_loader, desc="Val GAN", leave=False):
        input_x = input_x.to(hardware_device)
        target_y = target_y.to(hardware_device)
        with autocast(device_type=amp_dev_type, enabled=torch.cuda.is_available()):
            fake_image = Generator(input_x)
            l1 = F.l1_loss(fake_image, target_y)
        total_l1 += l1.item()
        total_psnr += calculate_psnr(fake_image, target_y).item()
        batch_count += 1
    return total_l1 / batch_count, total_psnr / batch_count

# ============================================================
# 6. MAIN EXECUTION FLOW
# ============================================================

def run_interpolation_project():
    start_time = time.time()
    
    # 1. Prepare Data
    print("\n--- 1. Robust Data Preparation ---")
    train_triplets, val_triplets, test_triplets = process_and_organize_data()

    training_dataset = ScanSliceSequenceDataset(train_triplets)
    validation_dataset = ScanSliceSequenceDataset(val_triplets)
    testing_dataset = ScanSliceSequenceDataset(test_triplets)

    train_loader = DataLoader(training_dataset, batch_size=BATCH_SIZE_PER_STEP, shuffle=True, num_workers=DATA_WORKER_THREADS, pin_memory=True)
    val_loader = DataLoader(validation_dataset, batch_size=BATCH_SIZE_PER_STEP, shuffle=False, num_workers=DATA_WORKER_THREADS, pin_memory=True)
    test_loader = DataLoader(testing_dataset, batch_size=BATCH_SIZE_PER_STEP, shuffle=False, num_workers=DATA_WORKER_THREADS, pin_memory=True)

    all_model_histories = {}

    # --- Train Standard Models ---
    base_sr_networks = {"SimpleConvolutionalModel": SimpleConvolutionalModel(), "DeeperConvolutionalModel": DeeperConvolutionalModel()}
    sr_networks = {}
    for name, m in base_sr_networks.items():
        m = m.to(processing_device)
        if USE_MULTI_GPU: m = nn.DataParallel(m)
        sr_networks[name] = m

    for name, model in sr_networks.items():
        print(f"\n===== Training {name} =====")
        optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
        scaler = GradScaler(amp_dev_type, enabled=torch.cuda.is_available())
        history = defaultdict(list)
        best_psnr_score = -1.0

        for epoch in range(1, TOTAL_TRAINING_EPOCHS + 1):
            print(f"--- Epoch {epoch}/{TOTAL_TRAINING_EPOCHS} ---")
            train_l, train_p = train_sr_model_one_epoch(model, train_loader, optimizer, scaler, processing_device)
            val_l, val_p = validate_sr_model(model, val_loader, processing_device)

            history["train_loss"].append(train_l); history["train_psnr"].append(train_p)
            history["val_loss"].append(val_l); history["val_psnr"].append(val_p)
            print(f"  Train: L1={train_l:.4f}, PSNR={train_p:.2f} dB | Val: L1={val_l:.4f}, PSNR={val_p:.2f} dB")

            if val_p > best_psnr_score:
                best_psnr_score = val_p
                torch.save(extract_model_weights(model), f"best_{name}.pth")
        
        all_model_histories[name] = history

    # --- Train GAN ---
    print("\n===== Training GAN =====")
    Generator = SliceSynthesizer().to(processing_device)
    Discriminator = RealityChecker().to(processing_device)
    if USE_MULTI_GPU:
        Generator = nn.DataParallel(Generator)
        Discriminator = nn.DataParallel(Discriminator)

    opt_G = torch.optim.Adam(Generator.parameters(), lr=LEARNING_RATE, betas=(0.5, 0.999))
    opt_D = torch.optim.Adam(Discriminator.parameters(), lr=LEARNING_RATE, betas=(0.5, 0.999))
    scaler_G = GradScaler(amp_dev_type, enabled=torch.cuda.is_available())
    scaler_D = GradScaler(amp_dev_type, enabled=torch.cuda.is_available())

    gan_history = defaultdict(list)
    best_gan_psnr_score = -1.0

    for epoch in range(1, TOTAL_TRAINING_EPOCHS + 1):
        print(f"--- Epoch {epoch}/{TOTAL_TRAINING_EPOCHS} ---")
        tg_l, td_l, tp_g = train_gan_model_one_epoch(Generator, Discriminator, train_loader, opt_G, opt_D, scaler_G, scaler_D, processing_device)
        vl1_g, vp_g = validate_gan_generator(Generator, val_loader, processing_device)

        gan_history["train_G_loss"].append(tg_l); gan_history["train_D_loss"].append(td_l); gan_history["train_psnr"].append(tp_g)
        gan_history["val_l1"].append(vl1_g); gan_history["val_psnr"].append(vp_g)
        print(f"  Train: G={tg_l:.4f}, D={td_l:.4f}, PSNR={tp_g:.2f} dB | Val: L1={vl1_g:.4f}, PSNR={vp_g:.2f} dB")

        if vp_g > best_gan_psnr_score:
            best_gan_psnr_score = vp_g
            torch.save(extract_model_weights(Generator), "best_SliceSynthesizer_G.pth")
            torch.save(extract_model_weights(Discriminator), "best_SliceSynthesizer_D.pth")

    all_model_histories["SliceSynthesizer"] = gan_history
    print("\nTraining complete.")

if __name__ == "__main__":
    run_interpolation_project()
# Out:
# /home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(
# PyTorch Version: 2.6.0+cu124
# Using hardware: cuda | Available GPUs: 2
# ✅ Parallel Processing enabled across 2 GPUs
#
# --- 1. Robust Data Preparation ---
# Total patients: 842 | Train=589, Val=126, Test=127
# Preparing Data:   0%|          | 0/842 [00:00<?, ?it/s]
# /scratch/local/20200790/ipykernel_3083611/3560836917.py:122: DeprecationWarning: BILINEAR is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BILINEAR instead.
#   resized_pil_image = pil_image.resize((target_dim[1], target_dim[0]), resample=Image.BILINEAR)
# ⚠️ Found corrupt image: Prostate-MRI-US-Biopsy-0479_slice_020.png. Skipping associated triplets.
# ⚠️ Found corrupt image: Prostate-MRI-US-Biopsy-0479_slice_020.png. Skipping associated triplets.
# ⚠️ Found corrupt image: Prostate-MRI-US-Biopsy-0479_slice_020.png. Skipping associated triplets.
# Data Ready: Train=41165, Val=7913, Test=8592
#
# ===== Training SimpleConvolutionalModel =====
# /home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 1, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# --- Epoch 1/20 ---
# /home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 1, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0645, PSNR=20.01 dB | Val: L1=0.0511, PSNR=24.32 dB
# --- Epoch 2/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0582, PSNR=20.39 dB | Val: L1=0.0472, PSNR=25.62 dB
# --- Epoch 3/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0576, PSNR=20.43 dB | Val: L1=0.0474, PSNR=25.28 dB
# --- Epoch 4/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0573, PSNR=20.44 dB | Val: L1=0.0468, PSNR=25.72 dB
# --- Epoch 5/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0571, PSNR=20.49 dB | Val: L1=0.0464, PSNR=25.75 dB
# --- Epoch 6/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0570, PSNR=20.48 dB | Val: L1=0.0466, PSNR=25.57 dB
# --- Epoch 7/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0568, PSNR=20.49 dB | Val: L1=0.0461, PSNR=25.86 dB
# --- Epoch 8/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():Exception ignored in:
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>  File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
#
# Traceback (most recent call last):
# assert self._parent_pid == os.getpid(), 'can only test a child process'Traceback (most recent call last):
#
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# AssertionError        : self._shutdown_workers()self._shutdown_workers()can only test a child process
#
#
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#         if w.is_alive():if w.is_alive():
#
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionErrorAssertionError: : can only test a child processcan only test a child process
#
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#         if w.is_alive():if w.is_alive():
#
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionErrorAssertionError: : can only test a child processcan only test a child process
#
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#         if w.is_alive():if w.is_alive():
#
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionErrorAssertionError: : can only test a child processcan only test a child process
#
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820><function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
#
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# Traceback (most recent call last):
#       File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# self._shutdown_workers()
#     self._shutdown_workers()  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#
#       File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# if w.is_alive():
# if w.is_alive():  File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#       File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# assert self._parent_pid == os.getpid(), 'can only test a child process'AssertionError
# : AssertionErrorcan only test a child process:
# can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#
#     Traceback (most recent call last):
# self._shutdown_workers()  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#         self._shutdown_workers()if w.is_alive():
#
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         if w.is_alive():assert self._parent_pid == os.getpid(), 'can only test a child process'
#
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# AssertionError    : assert self._parent_pid == os.getpid(), 'can only test a child process'can only test a child process
#
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# Exception ignored in:     <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>self._shutdown_workers()
#
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     if w.is_alive():    self._shutdown_workers()
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#       File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# if w.is_alive():AssertionError
# :   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# can only test a child process
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0567, PSNR=20.48 dB | Val: L1=0.0460, PSNR=25.81 dB
# --- Epoch 9/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0566, PSNR=20.51 dB | Val: L1=0.0460, PSNR=25.85 dB
# --- Epoch 10/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0565, PSNR=20.53 dB | Val: L1=0.0457, PSNR=25.96 dB
# --- Epoch 11/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0564, PSNR=20.54 dB | Val: L1=0.0459, PSNR=25.79 dB
# --- Epoch 12/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0563, PSNR=20.53 dB | Val: L1=0.0460, PSNR=25.74 dB
# --- Epoch 13/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0562, PSNR=20.56 dB | Val: L1=0.0457, PSNR=25.84 dB
# --- Epoch 14/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0562, PSNR=20.57 dB | Val: L1=0.0467, PSNR=25.79 dB
# --- Epoch 15/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0561, PSNR=20.58 dB | Val: L1=0.0454, PSNR=25.98 dB
# --- Epoch 16/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():Exception ignored in: Exception ignored in:
# <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820><function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>  File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#
#     Traceback (most recent call last):
# Traceback (most recent call last):
# assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#
#         AssertionErrorself._shutdown_workers(): self._shutdown_workers()
#
# can only test a child process  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#
#         if w.is_alive():if w.is_alive():
#
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionErrorAssertionError: can only test a child process: can only test a child process
#
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()    self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#
#       File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# if w.is_alive():
# if w.is_alive():  File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#       File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# assert self._parent_pid == os.getpid(), 'can only test a child process'AssertionError
# : AssertionErrorcan only test a child process:
# can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#
#     Traceback (most recent call last):
# self._shutdown_workers()  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#
#       File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# self._shutdown_workers()
#     if w.is_alive():  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#
#       File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# if w.is_alive():
# assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#     AssertionErrorassert self._parent_pid == os.getpid(), 'can only test a child process':
# can only test a child processAssertionError
# : can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Exception ignored in: Traceback (most recent call last):
# <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#
#     Traceback (most recent call last):
# self._shutdown_workers()  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#
#       File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# self._shutdown_workers()
# if w.is_alive():  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         if w.is_alive():assert self._parent_pid == os.getpid(), 'can only test a child process'
#
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# AssertionError    : assert self._parent_pid == os.getpid(), 'can only test a child process'can only test a child process
#
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# Exception ignored in:     <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>self._shutdown_workers()
#
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     if w.is_alive():    self._shutdown_workers()
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#       File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# if w.is_alive():AssertionError
# :   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# can only test a child process
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     Exception ignored in: self._shutdown_workers()<function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
#
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# Traceback (most recent call last):
#       File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# if w.is_alive():
#     self._shutdown_workers()  File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#       File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# if w.is_alive():AssertionError
# :   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# can only test a child process
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     Exception ignored in: self._shutdown_workers()<function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
#
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# Traceback (most recent call last):
#       File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# if w.is_alive():
# self._shutdown_workers()  File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
# assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#
# AssertionError    if w.is_alive():: can only test a child process
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0561, PSNR=20.58 dB | Val: L1=0.0456, PSNR=25.84 dB
# --- Epoch 17/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0560, PSNR=20.60 dB | Val: L1=0.0472, PSNR=25.23 dB
# --- Epoch 18/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0559, PSNR=20.63 dB | Val: L1=0.0458, PSNR=25.96 dB
# --- Epoch 19/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0559, PSNR=20.62 dB | Val: L1=0.0456, PSNR=26.01 dB
# --- Epoch 20/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0558, PSNR=20.63 dB | Val: L1=0.0454, PSNR=26.03 dB
#
# ===== Training DeeperConvolutionalModel =====
# --- Epoch 1/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0616, PSNR=20.17 dB | Val: L1=0.0469, PSNR=25.58 dB
# --- Epoch 2/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# Exception ignored in:     <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>Exception ignored in:
# self._shutdown_workers()<function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>Exception ignored in: Traceback (most recent call last):
#
#
# <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# Traceback (most recent call last):
#
#           File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# Traceback (most recent call last):
# self._shutdown_workers()if w.is_alive():      File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#
#
# self._shutdown_workers()      File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#
#     self._shutdown_workers()      File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# if w.is_alive():
# assert self._parent_pid == os.getpid(), 'can only test a child process'
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# if w.is_alive():    AssertionErrorif w.is_alive()::
#     can only test a child process  File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
# assert self._parent_pid == os.getpid(), 'can only test a child process'
#       File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
# assert self._parent_pid == os.getpid(), 'can only test a child process'AssertionError
# : assert self._parent_pid == os.getpid(), 'can only test a child process'AssertionErrorcan only test a child process
# :
# AssertionErrorcan only test a child process: Exception ignored in:
# can only test a child process<function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
#
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# Exception ignored in:     <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>Exception ignored in:
# self._shutdown_workers()<function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
# Exception ignored in:
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>Traceback (most recent call last):
#
#       File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# if w.is_alive():Traceback (most recent call last):
# self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     self._shutdown_workers()  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     self._shutdown_workers()
# assert self._parent_pid == os.getpid(), 'can only test a child process'
#       File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# if w.is_alive():    AssertionError    if w.is_alive():
# if w.is_alive()::   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
# can only test a child process
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#             assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'
#
#
# AssertionErrorAssertionErrorAssertionError: : : can only test a child processcan only test a child processcan only test a child process
#   Train: L1=0.0572, PSNR=20.43 dB | Val: L1=0.0463, PSNR=25.79 dB
# --- Epoch 3/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0568, PSNR=20.47 dB | Val: L1=0.0471, PSNR=25.40 dB
# --- Epoch 4/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0566, PSNR=20.53 dB | Val: L1=0.0472, PSNR=25.27 dB
# --- Epoch 5/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0564, PSNR=20.53 dB | Val: L1=0.0459, PSNR=25.78 dB
# --- Epoch 6/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
# ...
# Traceback (most recent call last):
#
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# self._shutdown_workers()
#     self._shutdown_workers()  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# self._shutdown_workers()
#
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# if w.is_alive():
#       File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# if w.is_alive():if w.is_alive():
#
#       File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process'
#         AssertionErrorassert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process':
#
# can only test a child processAssertionErrorAssertionError
# : : can only test a child processcan only test a child process
#
# IOStream.flush timed out
#   Train: L1=0.0552, PSNR=20.74 dB | Val: L1=0.0452, PSNR=26.15 dB
# --- Epoch 13/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0550, PSNR=20.77 dB | Val: L1=0.0459, PSNR=25.29 dB
# --- Epoch 14/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0549, PSNR=20.77 dB | Val: L1=0.0454, PSNR=25.39 dB
# --- Epoch 15/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0547, PSNR=20.80 dB | Val: L1=0.0449, PSNR=25.55 dB
# --- Epoch 16/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
#
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#       File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()    self._shutdown_workers()
# self._shutdown_workers()  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#
#
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#       File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# if w.is_alive():        if w.is_alive():
# if w.is_alive():  File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#
#       File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'AssertionError
#
# : AssertionErrorAssertionErrorcan only test a child process: :
# can only test a child processcan only test a child process
#
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>Exception ignored in: Exception ignored in:
# <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>Traceback (most recent call last):
# <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#       File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# self._shutdown_workers()
# self._shutdown_workers()self._shutdown_workers()  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#
#
#       File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# if w.is_alive():
#     if w.is_alive():  File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
# if w.is_alive():      File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
# assert self._parent_pid == os.getpid(), 'can only test a child process'      File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
# assert self._parent_pid == os.getpid(), 'can only test a child process'AssertionError
# assert self._parent_pid == os.getpid(), 'can only test a child process': AssertionErrorcan only test a child process
# : AssertionError
# can only test a child process:
# can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Traceback (most recent call last):
# Exception ignored in:
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#
#     self._shutdown_workers()Traceback (most recent call last):
# self._shutdown_workers()
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#             self._shutdown_workers()if w.is_alive():if w.is_alive():
#
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#       File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     if w.is_alive():    assert self._parent_pid == os.getpid(), 'can only test a child process'
# assert self._parent_pid == os.getpid(), 'can only test a child process'
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
# AssertionError    AssertionError: assert self._parent_pid == os.getpid(), 'can only test a child process': can only test a child process
# can only test a child process
# AssertionError
# : can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# Exception ignored in:   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>self._shutdown_workers()
#     self._shutdown_workers()Traceback (most recent call last):
#
#
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#             if w.is_alive():self._shutdown_workers()if w.is_alive():
#
#
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'    if w.is_alive():assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionError
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# AssertionError:     can only test a child process: assert self._parent_pid == os.getpid(), 'can only test a child process'can only test a child process
#
#
# AssertionError: can only test a child process
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820><function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# Exception ignored in:   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>self._shutdown_workers()
#
# Traceback (most recent call last):
# self._shutdown_workers()  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#
#       File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():    self._shutdown_workers()
# if w.is_alive():
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#       File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'    if w.is_alive():
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# : AssertionErrorcan only test a child process    : assert self._parent_pid == os.getpid(), 'can only test a child process'
# can only test a child process
#
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#
# Traceback (most recent call last):
#       File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# self._shutdown_workers()Exception ignored in:
# <function _MultiProcessingDataLoaderIter.__del__ at 0x14bd970b4820>self._shutdown_workers()  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#
#
#     Traceback (most recent call last):
#   File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# if w.is_alive():  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#
# if w.is_alive():      File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
# self._shutdown_workers()
#   File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/home/anany.sharma/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#
#     assert self._parent_pid == os.getpid(), 'can only test a child process'AssertionErrorif w.is_alive():
# :
# AssertionErrorcan only test a child process  File "/apps/jupyter/6.5.4/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# :
#     can only test a child processassert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionError: can only test a child process
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0546, PSNR=20.83 dB | Val: L1=0.0445, PSNR=26.11 dB
# --- Epoch 17/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0545, PSNR=20.84 dB | Val: L1=0.0442, PSNR=25.85 dB
# --- Epoch 18/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0544, PSNR=20.86 dB | Val: L1=0.0443, PSNR=26.15 dB
# --- Epoch 19/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0543, PSNR=20.88 dB | Val: L1=0.0438, PSNR=26.05 dB
# --- Epoch 20/20 ---
# Train SR:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val SR:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: L1=0.0542, PSNR=20.88 dB | Val: L1=0.0445, PSNR=25.75 dB
#
# ===== Training GAN =====
# --- Epoch 1/20 ---
# Train GAN:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val GAN:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: G=7.8721, D=0.4947, PSNR=19.59 dB | Val: L1=0.0545, PSNR=23.10 dB
# --- Epoch 2/20 ---
# Train GAN:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val GAN:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: G=7.2847, D=0.5422, PSNR=19.96 dB | Val: L1=0.0534, PSNR=23.86 dB
# --- Epoch 3/20 ---
# Train GAN:   0%|          | 0/5146 [00:00<?, ?it/s]
# Val GAN:   0%|          | 0/990 [00:00<?, ?it/s]
#   Train: G=7.1823, D=0.5540, PSNR=20.00 dB | Val: L1=0.0505, PSNR=24.67 dB
# --- Epoch 4/20 ---
# Train GAN:   0%|          | 0/5146 [00:00<?, ?it/s]
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#   Train: G=6.8810, D=0.5704, PSNR=20.33 dB | Val: L1=0.0488, PSNR=24.75 dB
# --- Epoch 16/20 ---
# Train GAN:   0%|          | 0/5146 [00:00<?, ?it/s]
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
import torch
print("PyTorch Version:", torch.__version__)
print("CUDA Version PyTorch uses:", torch.version.cuda)

if torch.cuda.is_available():
    print("GPU Name:", torch.cuda.get_device_name(0))
    print("GPU Capability Score:", torch.cuda.get_device_capability(0))
else:
    print("No GPU detected!")
# Out:
# PyTorch Version: 2.6.0+cu124
# CUDA Version PyTorch uses: 12.4
# GPU Name: NVIDIA L4
# GPU Capability Score: (8, 9)
